# %% [markdown]
# Name : Prince Titiya
# ID   : 202318010
# This segment of the assignment is designed to enhance understanding of the API call process and dataset creation.
# Utilize any freely available API endpoint on RapidAPI to generate a dataset.

# %%
import requests
import pandas as pd  # Import pandas library

def fetch_quotes():
    url = "https://apidojo-yahoo-finance-v1.p.rapidapi.com/auto-complete"
    querystring = {"q": "tesla", "region": "US"}

    headers = {
        "X-RapidAPI-Key": "aa48581c80msh6dc13c85a681dc4p143375jsn17249c4b6104",
        "X-RapidAPI-Host": "apidojo-yahoo-finance-v1.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)
    quotes = response.json().get('quotes', []) # Extracting data from response
    df = pd.DataFrame(quotes)
    return df

dfs = [fetch_quotes() for i in range(50)]    # iterating 50 times throught function and appends all dataframes
final_df = pd.concat(dfs, ignore_index=True)

final_df  #result
# Out:
#     exchange                        shortname quoteType   symbol   index  \
# 0        NMS                      Tesla, Inc.    EQUITY     TSLA  quotes
# 1        NGM  T-REX 2X Long Tesla Daily Targe       ETF     TSLT  quotes
# 2        NEO     TESLA, INC. CDR (CAD HEDGED)    EQUITY  TSLA.NE  quotes
# 3        NEO  TESLA (TSLA) YIELD SHARES PURPO       ETF  YTSL.NE  quotes
# 4        GER              TESLA INC. DL -,001    EQUITY   TL0.DE  quotes
# ..       ...                              ...       ...      ...     ...
# 345      NEO     TESLA, INC. CDR (CAD HEDGED)    EQUITY  TSLA.NE  quotes
# 346      NEO  TESLA (TSLA) YIELD SHARES PURPO       ETF  YTSL.NE  quotes
# 347      GER              TESLA INC. DL -,001    EQUITY   TL0.DE  quotes
# 348      LSE  LEVERAGE SHARES PUBLIC LIMITED     EQUITY   TSL3.L  quotes
# 349      NGM  T-Rex 2X Inverse Tesla Daily Ta       ETF     TSLZ  quotes
#
#          score typeDisp                                 longname exchDisp  \
# ...
